# %%
import turtle
wn= turtle.Screen()
t1=turtle.Turtle()

# %%
t1.fd(100)
t1.rt(90)
t1.fd(100)

# %%
def giyuk():
    t1.fd(100)
    t1.rt(90)
    t1.fd(100)

# %%
t1.home()
t1.clear()

# %%
giyuk()

# %%
def nieunat(x,y,z):
    t1.penup()
    t1.goto(x,y)
    t1.pendown()
    t1.rt(90)
    t1.fd(z)
    t1.lt(90)
    t1.fd(z)

# %%
t1.home()
t1.clear()

# %%
nieun()

# %%
t1.back(100)
nieun()

# %%
def digeut():
    t1.back(100)
    nieun()

# %%
digeut()

# %%
def rieul():
    giyuk()
    t1.lt(90)
    digeut()

# %%
rieul()

# %%
def mieum():
    giyuk()
    t1.penup()
    t1.home()
    t1.pendown()
    nieun()

# %%
mieum()

# %%
def giyuk(x):
    t1.fd(x)
    t1.rt(90)
    t1.fd(x)

# %%
giyuk(300)

# %%
def giyukat(x,y,z):
    t1.penup()
    t1.goto(x,y)
    t1.pendown()
    t1.fd(z)
    t1.rt(90)
    t1.fd(z)

# %%
giyukit(-100,100,200)

# %%
def mieumat(x,y,z):
    giyukat(x,y,z)
    t1.lt(90)
    nieunat(x,y,z)
    wn.exitonclick()

# %%
mieumat(-100,200,50)
