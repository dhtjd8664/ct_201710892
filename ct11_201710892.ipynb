# %% [markdown]
# <H1>안녕 이건 큰 글씨야!!</H1>

# %% [markdown]
# <H1>안녕 이건 큰 글씨야!!</H1>
# <H2>안녕 조금 작은 큰 글씨야!!</H2>
# <H3>안녕 이건 큰 글씨야!!</H3>
# <H30>안녕 이건 글씨야!</H30>

# %% [markdown]
# # 글씨
# ## 글씨
# ###### 글씨

# %% [markdown]
# * 도시
#     * 서울
#     * 시드니
#     * 뉴욕
#         * 1번가
#         * 33번가

# %%
print "hello"
print "1+2=",1+2
# Out:
# hello
# 1+2= 3

# %%
from PIL import Image

# %%
m = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1280.jpg")

# %%
m.show()

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(m)

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1280.gif")

# %%
myjpg = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1280.jpg")

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(myjpg)

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1280.png")

# %%
mypng = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1280.png")

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(mypng)

# %% [markdown]
# * jpg파일을 gif파일로 변환하기
#     * 파일 확장자를 gif로 적어준다.

# %% [markdown]
# * startswith() 기능 배우기

# %%
s="Hello World"
s.startswith('H')
# Out:
# True

# %%
"Hello world".startswith('h')
# Out:
# False

# %%
type(s)
# Out:
# str

# %%
s1="123"
s2="111"
type(s1)
# Out:
# str

# %%
int(s1)+int(s2)
# Out:
# 234

# %%
print s[0]=='H'
# Out:
# True

# %%
msg='She says "Good morning!"'
print msg
# Out:
# She says "Good morning!"

# %%
s.endswith('d')
# Out:
# True

# %%
for ch in s:
    print ch,
# Out:
# H e l l o   W o r l d

# %%
for i in range(0,11):
    print s[i],
# Out:
# H e l l o   W o r l d

# %%
for i in range(0,len(s)):
    print s[i],
# Out:
# H e l l o   W o r l d

# %%
s.index("Wor")
# Out:
# 6

# %%
s.strip('rld')
# Out:
# 'Hello Wo'

# %%
s1="Hello\n\tworld\n"
print s1
# Out:
# Hello
# 	world

# %%
print s1.strip()
# Out:
# Hello
# 	world

# %%
print s[10]
# Out:
# d

# %%
print s[-1]
# Out:
# d

# %%
print s[0:5]
# Out:
# Hello

# %%
print s[0:-1]
# Out:
# Hello Worl

# %%
print s[0:]
# Out:
# Hello World
